# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMG_PATH=r"C:\Users\camilo.restrepo\Desktop\OCR Demo\foto2.jpg"

# %%
reader=easyocr.Reader(['es'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
result=reader.readtext(IMG_PATH)
result
# Out:
# [([[7, 9], [93, 9], [93, 21], [7, 21]], '[otalde Itemns:', 0.4210075535031879),
#  ([[9, 21], [177, 21], [177, 35], [9, 35]],
#   'CIENTO CINCUENTA MIL PESOS',
#   0.6282502632021558),
#  ([[431, 21], [525, 21], [525, 37], [431, 37]],
#   'VALOR BRUTO',
#   0.5988582510030951),
#  ([[689, 23], [753, 23], [753, 37], [689, 37]],
#   '150,000,00',
#   0.5890130239653268),
#  ([[431, 43], [519, 43], [519, 57], [431, 57]],
#   'DESCUENTOS',
#   0.9921994181761914),
#  ([[725, 43], [753, 43], [753, 57], [725, 57]], '0.00', 0.8383969950686737),
#  ([[132, 62], [428, 62], [428, 70], [132, 70]],
#   'Dispuesto ENlaleY 1291 YceconfCehioaoccnlo;Aki(21yudel',
#   0.001336980850546119),
#  ([[7, 61], [119, 61], [119, 79], [7, 79]],
#   '[EsuIGoCEuEOIEERCOSTRT',
#   0.04131021509961842),
#  ([[8, 70], [98, 70], [98, 78], [8, 78]],
#   'Ccoigorscovarco',
#   0.2185388782617468),
#  ([[118, 70], [284, 70], [284, 78], [118, 78]],
#   'Bi Delesiatuo ribviarionacional',
#   0.047678890971694005),
# ...
